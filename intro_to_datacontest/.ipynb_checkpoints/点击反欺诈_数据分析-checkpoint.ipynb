# %% [markdown]
# # 数据读取

# %%
import pandas as pd
import numpy as np

import seaborn as sns
# %pylab inline

import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 100
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
train_df = pd.read_csv('data/data41574/train.csv')
test_df = pd.read_csv('data/data41574/test1.csv')
test_df2 = pd.read_csv('data/data41574/test2.csv')

# %%
# !head data/data41574/train.csv
# Out:
# android_id,apptype,carrier,dev_height,dev_ppi,dev_width,label,lan,media_id,ntt,os,osv,package,sid,timestamp,version,fea_hash,location,fea1_hash,cus_type
# 316361,1199,46000,0,0,0,1,,104,6,android,9,18,1438873,1.56E+12,8,2135019403,0,2329670524,601
# 135939,893,0,0,0,0,1,,19,6,android,8.1,0,1185582,1.56E+12,4,2782306428,1,2864801071,1000
# 399254,821,0,760,0,360,1,,559,0,android,8.1.0,0,1555716,1.56E+12,0,1392806005,2,628911675,696
# 68983,1004,46000,2214,0,1080,0,,129,2,android,8.1.0,0,1093419,1.56E+12,0,3562553457,3,1283809327,753
# 288999,1076,46000,2280,0,1080,1,zh-CN,64,2,android,8.0.0,0,1400089,1.56E+12,5,2364522023,4,1510695983,582
# 184658,788,46000,2196,480,1080,1,zh-CN,194,6,Android,8.1.0,35,1253737,1.56E+12,5,1655793887,5,1080320295,430
# 0,1106,46000,0,0,0,0,,39,0,android,9,123,1387136,1.56E+12,0,369486452,6,4190764663,411
# 0,1001,46000,760,0,360,1,zh-CN,29,2,Android,8.1.0,4,1597216,1.56E+12,0,3912031003,7,2627690535,411
# 646994,893,0,0,0,0,0,,19,6,android,8.1,0,1910989,1.56E+12,4,3307888762,8,2961728815,886

# %%
train_df.head(5)
# Out:
#    android_id  apptype  carrier  dev_height  dev_ppi  dev_width  label    lan  \
# 0      316361     1199    46000           0        0          0      1    NaN
# 1      135939      893        0           0        0          0      1    NaN
# 2      399254      821        0         760        0        360      1    NaN
# 3       68983     1004    46000        2214        0       1080      0    NaN
# 4      288999     1076    46000        2280        0       1080      1  zh-CN
#
#    media_id  ntt       os    osv  package      sid     timestamp version  \
# 0       104    6  android      9       18  1438873  1.560000e+12       8
# 1        19    6  android    8.1        0  1185582  1.560000e+12       4
# 2       559    0  android  8.1.0        0  1555716  1.560000e+12       0
# 3       129    2  android  8.1.0        0  1093419  1.560000e+12       0
# 4        64    2  android  8.0.0        0  1400089  1.560000e+12       5
#
#      fea_hash  location   fea1_hash  cus_type
# 0  2135019403         0  2329670524       601
# 1  2782306428         1  2864801071      1000
# 2  1392806005         2   628911675       696
# 3  3562553457         3  1283809327       753
# 4  2364522023         4  1510695983       582

# %%
#把label列移到最后一列
col = train_df.drop('label', axis = 1).columns.tolist() + ['label']
print(col)
print(col[:-1])
train_df = train_df[col]

test_df = test_df[col[:-1]]
test_df.head(3)
# Out:
# ['android_id', 'apptype', 'carrier', 'dev_height', 'dev_ppi', 'dev_width', 'lan', 'media_id', 'ntt', 'os', 'osv', 'package', 'sid', 'timestamp', 'version', 'fea_hash', 'location', 'fea1_hash', 'cus_type', 'label']
# ['android_id', 'apptype', 'carrier', 'dev_height', 'dev_ppi', 'dev_width', 'lan', 'media_id', 'ntt', 'os', 'osv', 'package', 'sid', 'timestamp', 'version', 'fea_hash', 'location', 'fea1_hash', 'cus_type']
#    android_id  apptype  carrier  dev_height  dev_ppi  dev_width    lan  \
# 0      317625     1181  46000.0      2196.0      2.0     1080.0     CN
# 1      435108      944  46003.0      2280.0      3.0     1080.0  zh-CN
# 2           0     1106  46000.0         0.0      0.0        0.0    NaN
#
#    media_id  ntt       os    osv  package      sid     timestamp version  \
# 0       639  2.0  Android  8.1.0      188  1440682  1.559872e+12       7
# 1       704  6.0  Android  8.1.0      221  1606824  1.559739e+12       3
# 2        39  2.0  android    5.1     1562  1774642  1.559614e+12       0
#
#      fea_hash  location   fea1_hash  cus_type
# 0  1672223856        57  3872258917       658
# 1  3767901757        23   129322164       943
# 2   454638703        30  4226678391       411

# %% [markdown]
# # 数据分析

# %% [markdown]
# ## 类型统计

# %%
# 数据类型字段统计， label为标签字段
train_df.dtypes
# Out:
# android_id      int64
# apptype         int64
# carrier         int64
# dev_height      int64
# dev_ppi         int64
# dev_width       int64
# lan            object
# media_id        int64
# ntt             int64
# os             object
# osv            object
# package         int64
# sid             int64
# timestamp     float64
# version        object
# fea_hash       object
# location        int64
# fea1_hash       int64
# cus_type        int64
# label           int64
# dtype: object

# %%
train_df.astype(object).describe(include='all')
# Out:
#         android_id  apptype  carrier  dev_height  dev_ppi  dev_width     lan  \
# count       500000   500000   500000      500000   500000     500000  316720
# unique      362258       89        5         798       92        346      21
# top              0     1001    46000           0        0       1080   zh-CN
# freq        126686   101248   359409      107014   383291     209914  244474
#
#         media_id     ntt       os     osv  package      sid     timestamp  \
# count     500000  500000   500000  493439   500000   500000  5.000000e+05
# unique       284       8        2     148     1950   500000  1.000000e+00
# top           29       2  android   8.1.0        0  1438873  1.560000e+12
# freq       93978  318597   303175  151419   131906        1  5.000000e+05
#
#        version  fea_hash  location   fea1_hash  cus_type   label
# count   500000    500000    500000      500000    500000  500000
# unique      17    402980       332        4959        58       2
# top          0  68083895        48  4190764663       411       0
# freq    292156       110     14932       28393    133055  257760

# %%
test_df.astype(object).describe(include='all')
# Out:
#         android_id  apptype   carrier  dev_height   dev_ppi  dev_width    lan  \
# count       150000   150000  150000.0    150000.0  150000.0   150000.0  94453
# unique      110483       78       5.0       600.0      58.0      238.0     20
# top              0     1001   46000.0         0.0       0.0     1080.0  zh-CN
# freq         38242    30377  107691.0     32199.0  115333.0    63071.0  73046
#
#         media_id       ntt       os     osv  package      sid     timestamp  \
# count     150000  150000.0   150000  148008   150000   150000  1.500000e+05
# unique       248       7.0        2     130     1293   150000  1.500000e+05
# top           29       2.0  android   8.1.0        0  1440682  1.559872e+12
# freq       28188   95538.0    91117   45224    39184        1  1.000000e+00
#
#        version  fea_hash  location   fea1_hash  cus_type
# count   150000    150000    150000      150000    150000
# unique      23    135084       332        2159        58
# top          0  51306679        48  4190764663       411
# freq     88113        36      4496        8726     40239

# %%
## 缺失值分析
plt.figure(figsize = (10,6))

plt.subplot(121)
train_df.isnull().mean(0).plot(kind = 'barh')
plt.ylabel('train feature')
plt.xlabel('missing percentage')
plt.title('Train')

plt.subplot(122)
test_df.isnull().mean(0).plot(kind = 'barh')
plt.ylabel('train feature')
plt.xlabel('missing percentage')
plt.title('Test')

plt.tight_layout()

# %% [markdown]
# ## 相关性分析

# %%
sns.heatmap(train_df.corr())
# Out:
# <AxesSubplot:>

# %%
train_df.corr().loc['label'].iloc[:-1].plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 探索性分析

# %%
train_df.head(3)
# Out:
#    android_id  apptype  carrier  dev_height  dev_ppi  dev_width  lan  \
# 0      316361     1199    46000           0        0          0  NaN
# 1      135939      893        0           0        0          0  NaN
# 2      399254      821        0         760        0        360  NaN
#
#    media_id  ntt       os    osv  package      sid     timestamp version  \
# 0       104    6  android      9       18  1438873  1.560000e+12       8
# 1        19    6  android    8.1        0  1185582  1.560000e+12       4
# 2       559    0  android  8.1.0        0  1555716  1.560000e+12       0
#
#      fea_hash  location   fea1_hash  cus_type  label
# 0  2135019403         0  2329670524       601      1
# 1  2782306428         1  2864801071      1000      1
# 2  1392806005         2   628911675       696      1

# %%
train_df.columns
# Out:
# Index(['android_id', 'apptype', 'carrier', 'dev_height', 'dev_ppi',
#        'dev_width', 'lan', 'media_id', 'ntt', 'os', 'osv', 'package', 'sid',
#        'timestamp', 'version', 'fea_hash', 'location', 'fea1_hash', 'cus_type',
#        'label'],
#       dtype='object')

# %% [markdown]
# ## 类别字段分析
